# %%
import numpy as np
import scipy.stats as stats
import csv
import seaborn as sns
# %matplotlib inline
import pandas as pd

# %%
bb = pd.read_csv('/Users/supermaxfederman/DSI-NYC-2/projects/projects-weekly/project-02/assets/billboard.csv', encoding='latin-1')

# %%
bb
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98¡
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %%
bb[(bb['genre']=='Rap')|(bb['genre']== 'R & B')]
# Out:
#      year               artist.inverted  \
# 17   2000                   Hill, Faith
# 29   2000               Jordan, Montell
# 31   2000                        Eminem
# 35   2000  Elliott, Missy "Misdemeanor"
# 47   2000                         Nelly
# 54   2000                       Ja Rule
# 57   2000                         Jay-Z
# 61   2000                      Mystikal
# 69   2000                      504 Boyz
# 71   2000                         Jay-Z
# 76   2000                   Lil Bow Wow
# 82   2000                      Ludacris
# 83   2000                     Lil' Zane
# 91   2000                           IMx
# 92   2000                       Dr. Dre
# 99   2000                       Dr. Dre
# 104  2000                       Da Brat
# 105  2000                           DMX
# 125  2000                         Musiq
# 134  2000                           Eve
# 139  2000                      Ice Cube
# 145  2000                  Jean, Wyclef
# ...

# %%
groups = ['Young Money', 'NWA', 'Wu Tang Clan', 'Bad Boyz', 'De La Soul']

# %%
pd.pivot_table(bb,index='time', aggfunc=[np.mean, max, min, np.std])
# Out:
#                   mean                              max                      \
#              x1st.week    year          artist.inverted        date.entered
# time
# 2,36,00 AM   75.000000  2000.0            Jackson, Alan    November 4, 2000
# 2,38,00 AM   78.000000  2000.0                  Dr. Dre        May 27, 2000
# 2,52,00 AM   89.000000  2000.0                Blink-182    December 4, 1999
# 2,53,00 AM   75.000000  2000.0            Tippin, Aaron       June 24, 2000
# 2,55,00 AM   80.500000  2000.0          Lawrence, Tracy    January 29, 2000
# 2,56,00 AM   86.500000  2000.0  Clark Family Experience   November 18, 2000
# 2,58,00 AM   96.000000  2000.0                    Trina   September 9, 2000
# 3,02,00 AM   99.000000  2000.0             Cagle, Chris    October 21, 2000
# 3,03,00 AM   71.000000  2000.0             Rimes, LeAnn    October 16, 1999
# 3,04,00 AM   86.666667  2000.0              Smash Mouth    October 30, 1999
# ...

# %%
### Hypothesis = On average, the highest performing songs will peak in the Summer. 
### Need to get scatter plot with aggregate plays on the y-axis and dates along the x-axis

# %%
aggplay = 'x1st.week' + 'x2nd.week' + 'x3rd.week'

# %%
# Out:
# 'x1st.weekx2nd.weekx3rd.week'
