# %%
import numpy as np
import scipy.stats as stats
import csv
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import random as random

# %%
bb = pd.read_csv('/Users/supermaxfederman/DSI-NYC-2/projects/projects-weekly/project-02/assets/billboard.csv', encoding='latin-1')

# %%
bb
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98¡
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %%
bb[(bb['genre']=='Rap')|(bb['genre']== 'R & B')]
# Out:
#      year               artist.inverted  \
# 17   2000                   Hill, Faith
# 29   2000               Jordan, Montell
# 31   2000                        Eminem
# 35   2000  Elliott, Missy "Misdemeanor"
# 47   2000                         Nelly
# 54   2000                       Ja Rule
# 57   2000                         Jay-Z
# 61   2000                      Mystikal
# 69   2000                      504 Boyz
# 71   2000                         Jay-Z
# 76   2000                   Lil Bow Wow
# 82   2000                      Ludacris
# 83   2000                     Lil' Zane
# 91   2000                           IMx
# 92   2000                       Dr. Dre
# 99   2000                       Dr. Dre
# 104  2000                       Da Brat
# 105  2000                           DMX
# 125  2000                         Musiq
# 134  2000                           Eve
# 139  2000                      Ice Cube
# 145  2000                  Jean, Wyclef
# ...

# %%
bb = bb.sort_values(by ='date.peaked')
rapbb = bb[(bb['genre']=='Rock')|(bb['genre']== 'Rock'n'roll')]
rapbb
# Out:
#   File "<ipython-input-26-bb48d18e5703>", line 2
#     rapbb = bb[(bb['genre']=='Rock')|(bb['genre']== 'Rock'n'roll')]
#                                                           ^
# SyntaxError: invalid syntax

# %%
bb = bb[(bb['genre']=='Rap')|(bb['genre']== "R & B")]

# %%
groups = ['Young Money', 'NWA', 'Wu Tang Clan', 'Bad Boyz', 'De La Soul']

# %%
pd.pivot_table(bb,index='date.entered', aggfunc=[np.mean, max, min, np.std])
# Out:
#                        mean                       max                          \
#                   x1st.week    year   artist.inverted       date.peaked genre
# date.entered
# April 1, 2000          89.5  2000.0               M2M      May 27, 2000   Pop
# February 19, 2000      69.0  2000.0              Hoku     April 8, 2000   Pop
# July 1, 2000           63.0  2000.0  Simpson, Jessica   August 12, 2000   Pop
# July 8, 2000           97.0  2000.0           A*Teens     July 29, 2000   Pop
# June 10, 2000          91.0  2000.0      Fabian, Lara   August 12, 2000   Pop
# June 17, 2000          69.0  2000.0      Moore, Mandy   August 12, 2000   Pop
# November 20, 1999      72.0  2000.0               M2M   January 8, 2000   Pop
# October 23, 1999       73.0  2000.0            Blaque  January 22, 2000   Pop
#
#                                                                         \
#                          time                         track x10th.week
# date.entered
# ...

# %%
### Hypothesis = On average, the highest performing songs will peak in the Summer. 
### Need to get scatter plot with aggregate plays on the y-axis and dates along the x-axis

# %%
bb['date.entered'] = pd.to_datetime(bb['date.entered'])
# Out:
# /Applications/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
bb
# Out:
#      year   artist.inverted                         track        time genre  \
# 34   2000            Blaque            Bring It All To Me  3,46,00 AM   Pop
# 81   2000  Simpson, Jessica  I Think I'm In Love With You  3,32,00 AM   Pop
# 84   2000               M2M         Don't Say You Love Me  3,41,00 AM   Pop
# 98   2000      Moore, Mandy           I Wanna Be With You  4,12,00 AM   Pop
# 110  2000              Hoku           Another Dumb Blonde  3,47,00 AM   Pop
# 129  2000      Fabian, Lara             I Will Love Again  3,43,00 AM   Pop
# 217  2000               M2M                 Mirror Mirror  3,19,00 AM   Pop
# 301  2000         Anastacia                I'm Outta Love  4,01,00 AM   Pop
# 304  2000           A*Teens                 Dancing Queen  3,44,00 AM   Pop
#
#     date.entered       date.peaked  x1st.week x2nd.week x3rd.week    ...      \
# 34    1999-10-23  January 22, 2000         73        63        50    ...
# ...

# %%
bb2= bb.groupby([bb['date.entered'].dt.year, bb['date.entered'].dt.month])['date.entered'].count().to_frame()

# %%
bb2['date.entered'].plot(kind='bar')

# %%
bb['date.peaked'] = pd.to_datetime(bb['date.peaked'])
print(bb['date.peaked'])
# Out:
# 34    2000-01-22
# 81    2000-08-12
# 84    2000-01-08
# 98    2000-08-12
# 110   2000-04-08
# 129   2000-08-12
# 217   2000-05-27
# 301   2000-04-01
# 304   2000-07-29
# Name: date.peaked, dtype: datetime64[ns]
# /Applications/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
bbpeak = bb.groupby([bb['date.peaked'].dt.year, bb['date.peaked'].dt.month])['date.peaked'].count().to_frame()

# %%
bbpeak['date.peaked'].plot(kind='bar')

# %%
bbpeak.sort_values('date.peaked')[-3:]
# Out:
#                          date.peaked
# date.peaked date.peaked
# 2000        1                      2
#             4                      2
#             8                      3

# %%
peakseries = bbpeak['date.peaked'].values

# %%
peakseries
# Out:
# array([40, 22, 26, 30, 22, 21, 26, 26, 30, 22, 15, 37])

# %%
peakseries.max()
# Out:
# 40

# %%
peaklist = []

for i in peakseries: 
    peaklist.append(i)
    
peaklist
# Out:
# [40, 22, 26, 30, 22, 21, 26, 26, 30, 22, 15, 37]

# %%
sorted(peaklist)[-4:]
# Out:
# [30, 30, 37, 40]

# %%
weeks= bb.loc[0,[x for x in bb.columns if 'week' in x]]

# %%
weeks2 = 101 - weeks.replace('*', 0).astype(int)

# %%
range(len(weeks2))
# Out:
# range(0, 76)

# %%
x = list(range(len(weeks2)))

# %%
plt.plot(x, weeks2)

# %%
weekly= bb.loc[random.randint(1, 100),[x for x in bb.columns if 'week' in x]]
weeklyA= bb.loc[random.randint(1, 100),[x for x in bb.columns if 'week' in x]]
weeklyB= bb.loc[random.randint(1, 100),[x for x in bb.columns if 'week' in x]]
weeklyC= bb.loc[random.randint(1, 100),[x for x in bb.columns if 'week' in x]]
weeklyD= bb.loc[random.randint(1, 100),[x for x in bb.columns if 'week' in x]]
weeklyE= bb.loc[random.randint(1, 100),[x for x in bb.columns if 'week' in x]]

# %%
weekly2 = 101 - weekly.replace('*', 0).astype(float)
weekly3 = 101 - weeklyA.replace('*', 0).astype(float)
weekly4 = 101 - weeklyB.replace('*', 0).astype(float)
weekly5 = 101 - weeklyC.replace('*', 0).astype(float)
weekly6 = 101 - weeklyC.replace('*', 0).astype(float)
weekly7 = 101 - weeklyC.replace('*', 0).astype(float)

# %%
range(len(weekly2))
range(len(weekly3))
range(len(weekly4))
range(len(weekly5))
range(len(weekly6))
range(len(weekly7))
# Out:
# range(0, 76)

# %%
x = list(range(len(weekly2)))

# %%
plt.plot(x, weekly2, color='r')
plt.plot(x, weekly3, color='b')
plt.plot(x, weekly4, color='g')
plt.plot(x, weekly5, color='y')
plt.plot(x, weekly6, color='c')
plt.plot(x, weekly7, color='m')

# %%
### y-axis = position, x-axis=week

# %%
### do bar graphs of how many songs were released each month, how many peaked each month
