# %%
import pandas as pd
import numpy as np

dc = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/comic-characters/dc-wikia-data.csv")
mv = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/comic-characters/marvel-wikia-data.csv")

#column continuity
mv.rename(columns={'Year':'YEAR'}, inplace=True)

#DC/MV dummies
mv['dc_mv'] = 1
dc['dc_mv'] = 0

#concat df
df = pd.concat([mv, dc], axis = 0)

#rename columns
df.columns = ['page_id', 'name', 'urlslug', 'ID', 'ALIGN', 'EYE', 'HAIR', 'SEX', 'GSM', 'ALIVE', 'APPEARANCES', '1st_APPEARANCE', 'YEAR', 'dc_mv']
df['GSM'] = df['GSM'].fillna('Sraight')
df['HAIR'] = df['HAIR'].fillna('None')
df['EYE'] = df['EYE'].fillna('None')

#resetting index
df.reset_index()
df.drop(['page_id','urlslug'], axis=1, inplace=True)
df.dropna(inplace=True)

df
# Out:
#                                      name                ID  \
# 0               Spider-Man (Peter Parker)   Secret Identity
# 1         Captain America (Steven Rogers)   Public Identity
# 2     Wolverine (James \"Logan\" Howlett)   Public Identity
# 3       Iron Man (Anthony \"Tony\" Stark)   Public Identity
# 4                     Thor (Thor Odinson)  No Dual Identity
# 5              Benjamin Grimm (Earth-616)   Public Identity
# 6               Reed Richards (Earth-616)   Public Identity
# 7              Hulk (Robert Bruce Banner)   Public Identity
# 8               Scott Summers (Earth-616)   Public Identity
# 9              Jonathan Storm (Earth-616)   Public Identity
# 10                Henry McCoy (Earth-616)   Public Identity
# 11                Susan Storm (Earth-616)   Public Identity
# 13               Ororo Munroe (Earth-616)   Public Identity
# 14             Clinton Barton (Earth-616)   Public Identity
# 15            Matthew Murdock (Earth-616)   Public Identity
# 16            Stephen Strange (Earth-616)   Public Identity
# 17           Mary Jane Watson (Earth-616)  No Dual Identity
# 18         John Jonah Jameson (Earth-616)  No Dual Identity
# 19               Robert Drake (Earth-616)   Secret Identity
# 20                  Henry Pym (Earth-616)   Public Identity
# 21             Charles Xavier (Earth-616)   Public Identity
# 22     Warren Worthington III (Earth-616)   Public Identity
# 23             Piotr Rasputin (Earth-616)   Secret Identity
# 24             Wanda Maximoff (Earth-616)   Public Identity
# 25              Nicholas Fury (Earth-616)  No Dual Identity
# 26             Janet van Dyne (Earth-616)   Public Identity
# 27                  Jean Grey (Earth-616)   Public Identity
# 28           Natalia Romanova (Earth-616)   Public Identity
# 29                Kurt Wagner (Earth-616)   Secret Identity
# 30                     Vision (Earth-616)   Secret Identity
# ...                                   ...               ...
# 6461            Sophia Santos (New Earth)   Public Identity
# 6463                Darklight (New Earth)   Secret Identity
# 6464                Doc Scary (New Earth)   Secret Identity
# 6475                   Hoogin (New Earth)   Public Identity
# 6477                   Stanga (New Earth)   Public Identity
# 6482                 Heimdall (New Earth)   Secret Identity
# 6483           Lyndon Johnson (New Earth)   Public Identity
# 6486                Toymaster (Earth-One)   Secret Identity
# 6492              Supreme One (New Earth)   Secret Identity
# 6493       Typhoon (O.G.R.E.) (New Earth)   Secret Identity
# 6494             Zedabon Zarr (New Earth)   Secret Identity
# 6496                Dean Farr (New Earth)   Secret Identity
# 6498              Otto Fisher (New Earth)   Secret Identity
# 6499                  Agantha (New Earth)   Secret Identity
# 6501                 Aluminum (New Earth)   Secret Identity
# 6502                   Barium (New Earth)   Secret Identity
# 6503                  Calcium (New Earth)   Secret Identity
# 6504                Plutonium (New Earth)   Secret Identity
# 6505                   Sodium (New Earth)   Secret Identity
# 6506   William Magnus (robot) (New Earth)   Secret Identity
# 6507                Zirconium (New Earth)   Secret Identity
# 6508                     Boka (New Earth)   Public Identity
# 6511         Ferenc Aldebaran (New Earth)   Public Identity
# 6515               John Dolan (Earth-One)   Public Identity
# 6516             Clyde Mardon (New Earth)   Public Identity
# 6521           Jeffrey Graham (New Earth)   Public Identity
# 6522                      Kay (New Earth)   Public Identity
# 6523          Carnie Callahan (New Earth)   Public Identity
# 6526           Green Arrow (Oliver Queen)   Secret Identity
# 6528             Robert Mason (New Earth)   Secret Identity
#
#                    ALIGN                 EYE         HAIR                SEX  \
# 0        Good Characters          Hazel Eyes   Brown Hair    Male Characters
# 1        Good Characters           Blue Eyes   White Hair    Male Characters
# 2     Neutral Characters           Blue Eyes   Black Hair    Male Characters
# 3        Good Characters           Blue Eyes   Black Hair    Male Characters
# 4        Good Characters           Blue Eyes   Blond Hair    Male Characters
# 5        Good Characters           Blue Eyes      No Hair    Male Characters
# 6        Good Characters          Brown Eyes   Brown Hair    Male Characters
# 7        Good Characters          Brown Eyes   Brown Hair    Male Characters
# 8     Neutral Characters          Brown Eyes   Brown Hair    Male Characters
# 9        Good Characters           Blue Eyes   Blond Hair    Male Characters
# 10       Good Characters           Blue Eyes    Blue Hair    Male Characters
# 11       Good Characters           Blue Eyes   Blond Hair  Female Characters
# 13       Good Characters           Blue Eyes   White Hair  Female Characters
# 14       Good Characters           Blue Eyes   Blond Hair    Male Characters
# 15       Good Characters           Blue Eyes     Red Hair    Male Characters
# 16       Good Characters           Grey Eyes   Black Hair    Male Characters
# 17       Good Characters          Green Eyes     Red Hair  Female Characters
# 18    Neutral Characters           Blue Eyes   Black Hair    Male Characters
# 19       Good Characters          Brown Eyes   Brown Hair    Male Characters
# 20       Good Characters           Blue Eyes   Blond Hair    Male Characters
# 21       Good Characters           Blue Eyes         Bald    Male Characters
# 22       Good Characters           Blue Eyes   Blond Hair    Male Characters
# 23       Good Characters           Blue Eyes   Black Hair    Male Characters
# 10    1963.0      1
# 11    1961.0      1
# 13    1975.0      1
# 14    1964.0      1
# 15    1964.0      1
# 16    1963.0      1
# 17    1965.0      1
# 18    1963.0      1
# 19    1963.0      1
# 20    1962.0      1
# 21    1963.0      1
# 22    1963.0      1
# 23    1975.0      1
# 24    1964.0      1
# 25    1963.0      1
# 26    1963.0      1
# 27    1963.0      1
# 28    1964.0      1
# 29    1975.0      1
# 30    1968.0      1
# ...      ...    ...
# 6461  1978.0      0
# 6463  1977.0      0
# 6464  1976.0      0
# 6475  1972.0      0
# 6477  1972.0      0
# 6482  1967.0      0
# 6483  1967.0      0
# 6486  1967.0      0
# 6492  1966.0      0
# 6493  1966.0      0
# 6494  1966.0      0
# 6496  1965.0      0
# 6498  1965.0      0
# 6499  1964.0      0
# 6501  1963.0      0
# 6502  1963.0      0
# 6503  1963.0      0
# 6504  1963.0      0
# 6505  1963.0      0
# 6506  1963.0      0
# 6507  1963.0      0
# 6508  1962.0      0
# 6511  1962.0      0
# 6515  1961.0      0
# 6516  1960.0      0
# 6521  1951.0      0
# 6522  1946.0      0
# 6523  1944.0      0
# 6526  1941.0      0
# 6528  1941.0      0
#
# [13832 rows x 12 columns]

# %%
mv[mv['GSM'] == "straight"]
# Out:
# Empty DataFrame
# Columns: [page_id, name, urlslug, ID, ALIGN, EYE, HAIR, SEX, GSM, ALIVE, APPEARANCES, FIRST APPEARANCE, YEAR, dc_mv]
# Index: []

# %%
rdiverse =
# Out:
# 0          Male Characters
# 1          Male Characters
# 2          Male Characters
# 3          Male Characters
# 4          Male Characters
# 5          Male Characters
# 6          Male Characters
# 7          Male Characters
# 8          Male Characters
# 9          Male Characters
# 10         Male Characters
# 11       Female Characters
# 12         Male Characters
# 13       Female Characters
# 14         Male Characters
# 15         Male Characters
# 16         Male Characters
# 17       Female Characters
# 18         Male Characters
# 19         Male Characters
# 20         Male Characters
# 21         Male Characters
# 22         Male Characters
# 23         Male Characters
# 24       Female Characters
# 25         Male Characters
# 26       Female Characters
# 27       Female Characters
# 28       Female Characters
# 29         Male Characters
#                ...
# 16346      Male Characters
# 16347                  NaN
# 16348                  NaN
# 16349      Male Characters
# 16350                  NaN
# 16351      Male Characters
# 16352      Male Characters
# 16353      Male Characters
# 16354      Male Characters
# 16355      Male Characters
# 16356      Male Characters
# 16357      Male Characters
# 16358    Female Characters
# 16359      Male Characters
# 16360    Female Characters
# 16361    Female Characters
# 16362    Female Characters
# 16363      Male Characters
# 16364      Male Characters
# 16365      Male Characters
# 16366    Female Characters
# 16367      Male Characters
# 16368    Female Characters
# 16369    Female Characters
# 16370                  NaN
# 16371      Male Characters
# 16372      Male Characters
# 16373      Male Characters
# 16374      Male Characters
# 16375                  NaN
# Name: SEX, dtype: object
