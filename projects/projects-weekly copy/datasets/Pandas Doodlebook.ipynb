# %%
import pandas as pd

# how to read in a csv
df = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/car/Salaries.csv')
df
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 0             1       Prof          B             19           18    Male
# 1             2       Prof          B             20           16    Male
# 2             3   AsstProf          B              4            3    Male
# 3             4       Prof          B             45           39    Male
# 4             5       Prof          B             40           41    Male
# 5             6  AssocProf          B              6            6    Male
# 6             7       Prof          B             30           23    Male
# 7             8       Prof          B             45           45    Male
# 8             9       Prof          B             21           20    Male
# 9            10       Prof          B             18           18  Female
# 10           11  AssocProf          B             12            8    Male
# 11           12   AsstProf          B              7            2    Male
# 12           13   AsstProf          B              1            1    Male
# 13           14   AsstProf          B              2            0    Male
# 14           15       Prof          B             20           18    Male
# 15           16       Prof          B             12            3    Male
# 16           17       Prof          B             19           20    Male
# 17           18       Prof          A             38           34    Male
# 18           19       Prof          A             37           23    Male
# 19           20       Prof          A             39           36  Female
# 20           21       Prof          A             31           26    Male
# 21           22       Prof          A             36           31    Male
# 22           23       Prof          A             34           30    Male
# 23           24       Prof          A             24           19    Male
# 24           25  AssocProf          A             13            8  Female
# 25           26       Prof          A             21            8    Male
# 26           27       Prof          A             35           23    Male
# 27           28   AsstProf          B              5            3    Male
# 28           29   AsstProf          B             11            0    Male
# 29           30       Prof          B             12            8    Male
# ..          ...        ...        ...            ...          ...     ...
# 367         368  AssocProf          A             10            1    Male
# 368         369       Prof          A             35           30    Male
# 369         370       Prof          A             33           31    Male
# 370         371  AssocProf          A             13            8    Male
# 371         372       Prof          A             23           20    Male
# 372         373       Prof          A             12            7    Male
# 373         374       Prof          A             30           26    Male
# 374         375       Prof          A             27           19    Male
# 375         376       Prof          A             28           26    Male
# 376         377   AsstProf          A              4            1    Male
# 377         378   AsstProf          A              6            3    Male
# 378         379       Prof          A             38           38    Male
# 379         380  AssocProf          A             11            8    Male
# 380         381   AsstProf          A              8            3    Male
# 381         382       Prof          A             27           23    Male
# 382         383  AssocProf          A              8            5    Male
# 383         384       Prof          A             44           44    Male
# 384         385       Prof          A             27           21    Male
# 385         386       Prof          A             15            9    Male
# 386         387       Prof          A             29           27    Male
# 387         388       Prof          A             29           15    Male
# 388         389       Prof          A             38           36    Male
# 389         390       Prof          A             33           18    Male
# 390         391       Prof          A             40           19    Male
# 391         392       Prof          A             30           19    Male
# 392         393       Prof          A             33           30    Male
# 393         394       Prof          A             31           19    Male
# 394         395       Prof          A             42           25    Male
# 395         396       Prof          A             25           15    Male
# 396         397   AsstProf          A              8            4    Male
#
#      salary
# 0    139750
# 1    173200
# 2     79750
# 3    115000
# 4    141500
# 5     97000
# 6    175000
# 7    147765
# 8    119250
# 9    129000
# 10   119800
# 11    79800
# 12    77700
# 13    78000
# 14   104800
# 15   117150
# 16   101000
# 17   103450
# 18   124750
# 19   137000
# 20    89565
# 21   102580
# 22    93904
# 23   113068
# 24    74830
# 25   106294
# 26   134885
# 27    82379
# 28    77000
# 29   118223
# ..      ...
# 367  108413
# 368  131950
# 369  134690
# 370   78182
# 371  110515
# 372  109707
# 373  136660
# 374  103275
# 375  103649
# 376   74856
# 377   77081
# 378  150680
# 379  104121
# 380   75996
# 381  172505
# 382   86895
# 383  105000
# 384  125192
# 385  114330
# 386  139219
# 387  109305
# 388  119450
# 389  186023
# 390  166605
# 391  151292
# 392  103106
# 393  150564
# 394  101738
# 395   95329
# 396   81035
#
# [397 rows x 7 columns]

# %%
df = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/car/Salaries.csv',\
                 usecols=range(1, 5))
df
# Out:
#           rank discipline  yrs.since.phd  yrs.service
# 0         Prof          B             19           18
# 1         Prof          B             20           16
# 2     AsstProf          B              4            3
# 3         Prof          B             45           39
# 4         Prof          B             40           41
# 5    AssocProf          B              6            6
# 6         Prof          B             30           23
# 7         Prof          B             45           45
# 8         Prof          B             21           20
# 9         Prof          B             18           18
# 10   AssocProf          B             12            8
# 11    AsstProf          B              7            2
# 12    AsstProf          B              1            1
# 13    AsstProf          B              2            0
# 14        Prof          B             20           18
# 15        Prof          B             12            3
# 16        Prof          B             19           20
# 17        Prof          A             38           34
# 18        Prof          A             37           23
# 19        Prof          A             39           36
# 20        Prof          A             31           26
# 21        Prof          A             36           31
# 22        Prof          A             34           30
# 23        Prof          A             24           19
# 24   AssocProf          A             13            8
# 25        Prof          A             21            8
# 26        Prof          A             35           23
# 27    AsstProf          B              5            3
# 28    AsstProf          B             11            0
# 29        Prof          B             12            8
# ..         ...        ...            ...          ...
# 367  AssocProf          A             10            1
# 368       Prof          A             35           30
# 369       Prof          A             33           31
# 370  AssocProf          A             13            8
# 371       Prof          A             23           20
# 372       Prof          A             12            7
# 373       Prof          A             30           26
# 374       Prof          A             27           19
# 375       Prof          A             28           26
# 376   AsstProf          A              4            1
# 377   AsstProf          A              6            3
# 378       Prof          A             38           38
# 379  AssocProf          A             11            8
# 380   AsstProf          A              8            3
# 381       Prof          A             27           23
# 382  AssocProf          A              8            5
# 383       Prof          A             44           44
# 384       Prof          A             27           21
# 385       Prof          A             15            9
# 386       Prof          A             29           27
# 387       Prof          A             29           15
# 388       Prof          A             38           36
# 389       Prof          A             33           18
# 390       Prof          A             40           19
# 391       Prof          A             30           19
# 392       Prof          A             33           30
# 393       Prof          A             31           19
# 394       Prof          A             42           25
# 395       Prof          A             25           15
# 396   AsstProf          A              8            4
#
# [397 rows x 4 columns]

# %%
df = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/car/Salaries.csv',\
                 usecols=[x for x in range (0,8) if x% 2==0])
df
# Out:
#      Unnamed: 0 discipline  yrs.service  salary
# 0             1          B           18  139750
# 1             2          B           16  173200
# 2             3          B            3   79750
# 3             4          B           39  115000
# 4             5          B           41  141500
# 5             6          B            6   97000
# 6             7          B           23  175000
# 7             8          B           45  147765
# 8             9          B           20  119250
# 9            10          B           18  129000
# 10           11          B            8  119800
# 11           12          B            2   79800
# 12           13          B            1   77700
# 13           14          B            0   78000
# 14           15          B           18  104800
# 15           16          B            3  117150
# 16           17          B           20  101000
# 17           18          A           34  103450
# 18           19          A           23  124750
# 19           20          A           36  137000
# 20           21          A           26   89565
# 21           22          A           31  102580
# 22           23          A           30   93904
# 23           24          A           19  113068
# 24           25          A            8   74830
# 25           26          A            8  106294
# 26           27          A           23  134885
# 27           28          B            3   82379
# 28           29          B            0   77000
# 29           30          B            8  118223
# ..          ...        ...          ...     ...
# 367         368          A            1  108413
# 368         369          A           30  131950
# 369         370          A           31  134690
# 370         371          A            8   78182
# 371         372          A           20  110515
# 372         373          A            7  109707
# 373         374          A           26  136660
# 374         375          A           19  103275
# 375         376          A           26  103649
# 376         377          A            1   74856
# 377         378          A            3   77081
# 378         379          A           38  150680
# 379         380          A            8  104121
# 380         381          A            3   75996
# 381         382          A           23  172505
# 382         383          A            5   86895
# 383         384          A           44  105000
# 384         385          A           21  125192
# 385         386          A            9  114330
# 386         387          A           27  139219
# 387         388          A           15  109305
# 388         389          A           36  119450
# 389         390          A           18  186023
# 390         391          A           19  166605
# 391         392          A           19  151292
# 392         393          A           30  103106
# 393         394          A           19  150564
# 394         395          A           25  101738
# 395         396          A           15   95329
# 396         397          A            4   81035
#
# [397 rows x 4 columns]

# %%
df = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/car/Salaries.csv')
df
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 0             1       Prof          B             19           18    Male
# 1             2       Prof          B             20           16    Male
# 2             3   AsstProf          B              4            3    Male
# 3             4       Prof          B             45           39    Male
# 4             5       Prof          B             40           41    Male
# 5             6  AssocProf          B              6            6    Male
# 6             7       Prof          B             30           23    Male
# 7             8       Prof          B             45           45    Male
# 8             9       Prof          B             21           20    Male
# 9            10       Prof          B             18           18  Female
# 10           11  AssocProf          B             12            8    Male
# 11           12   AsstProf          B              7            2    Male
# 12           13   AsstProf          B              1            1    Male
# 13           14   AsstProf          B              2            0    Male
# 14           15       Prof          B             20           18    Male
# 15           16       Prof          B             12            3    Male
# 16           17       Prof          B             19           20    Male
# 17           18       Prof          A             38           34    Male
# 18           19       Prof          A             37           23    Male
# 19           20       Prof          A             39           36  Female
# 20           21       Prof          A             31           26    Male
# 21           22       Prof          A             36           31    Male
# 22           23       Prof          A             34           30    Male
# 23           24       Prof          A             24           19    Male
# 24           25  AssocProf          A             13            8  Female
# 25           26       Prof          A             21            8    Male
# 26           27       Prof          A             35           23    Male
# 27           28   AsstProf          B              5            3    Male
# 28           29   AsstProf          B             11            0    Male
# 29           30       Prof          B             12            8    Male
# ..          ...        ...        ...            ...          ...     ...
# 367         368  AssocProf          A             10            1    Male
# 368         369       Prof          A             35           30    Male
# 369         370       Prof          A             33           31    Male
# 370         371  AssocProf          A             13            8    Male
# 371         372       Prof          A             23           20    Male
# 372         373       Prof          A             12            7    Male
# 373         374       Prof          A             30           26    Male
# 374         375       Prof          A             27           19    Male
# 375         376       Prof          A             28           26    Male
# 376         377   AsstProf          A              4            1    Male
# 377         378   AsstProf          A              6            3    Male
# 378         379       Prof          A             38           38    Male
# 379         380  AssocProf          A             11            8    Male
# 380         381   AsstProf          A              8            3    Male
# 381         382       Prof          A             27           23    Male
# 382         383  AssocProf          A              8            5    Male
# 383         384       Prof          A             44           44    Male
# 384         385       Prof          A             27           21    Male
# 385         386       Prof          A             15            9    Male
# 386         387       Prof          A             29           27    Male
# 387         388       Prof          A             29           15    Male
# 388         389       Prof          A             38           36    Male
# 389         390       Prof          A             33           18    Male
# 390         391       Prof          A             40           19    Male
# 391         392       Prof          A             30           19    Male
# 392         393       Prof          A             33           30    Male
# 393         394       Prof          A             31           19    Male
# 394         395       Prof          A             42           25    Male
# 395         396       Prof          A             25           15    Male
# 396         397   AsstProf          A              8            4    Male
#
#      salary
# 0    139750
# 1    173200
# 2     79750
# 3    115000
# 4    141500
# 5     97000
# 6    175000
# 7    147765
# 8    119250
# 9    129000
# 10   119800
# 11    79800
# 12    77700
# 13    78000
# 14   104800
# 15   117150
# 16   101000
# 17   103450
# 18   124750
# 19   137000
# 20    89565
# 21   102580
# 22    93904
# 23   113068
# 24    74830
# 25   106294
# 26   134885
# 27    82379
# 28    77000
# 29   118223
# ..      ...
# 367  108413
# 368  131950
# 369  134690
# 370   78182
# 371  110515
# 372  109707
# 373  136660
# 374  103275
# 375  103649
# 376   74856
# 377   77081
# 378  150680
# 379  104121
# 380   75996
# 381  172505
# 382   86895
# 383  105000
# 384  125192
# 385  114330
# 386  139219
# 387  109305
# 388  119450
# 389  186023
# 390  166605
# 391  151292
# 392  103106
# 393  150564
# 394  101738
# 395   95329
# 396   81035
#
# [397 rows x 7 columns]

# %%
df.head()
# Out:
#    Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0           1      Prof          B             19           18  Male  139750
# 1           2      Prof          B             20           16  Male  173200
# 2           3  AsstProf          B              4            3  Male   79750
# 3           4      Prof          B             45           39  Male  115000
# 4           5      Prof          B             40           41  Male  141500

# %%
df.tail()
# Out:
#      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 392         393      Prof          A             33           30  Male  103106
# 393         394      Prof          A             31           19  Male  150564
# 394         395      Prof          A             42           25  Male  101738
# 395         396      Prof          A             25           15  Male   95329
# 396         397  AsstProf          A              8            4  Male   81035

# %%
df.head(20)
# Out:
#     Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 0            1       Prof          B             19           18    Male
# 1            2       Prof          B             20           16    Male
# 2            3   AsstProf          B              4            3    Male
# 3            4       Prof          B             45           39    Male
# 4            5       Prof          B             40           41    Male
# 5            6  AssocProf          B              6            6    Male
# 6            7       Prof          B             30           23    Male
# 7            8       Prof          B             45           45    Male
# 8            9       Prof          B             21           20    Male
# 9           10       Prof          B             18           18  Female
# 10          11  AssocProf          B             12            8    Male
# 11          12   AsstProf          B              7            2    Male
# 12          13   AsstProf          B              1            1    Male
# 13          14   AsstProf          B              2            0    Male
# 14          15       Prof          B             20           18    Male
# 15          16       Prof          B             12            3    Male
# 16          17       Prof          B             19           20    Male
# 17          18       Prof          A             38           34    Male
# 18          19       Prof          A             37           23    Male
# 19          20       Prof          A             39           36  Female
#
#     salary
# 0   139750
# 1   173200
# 2    79750
# 3   115000
# 4   141500
# 5    97000
# 6   175000
# 7   147765
# 8   119250
# 9   129000
# 10  119800
# 11   79800
# 12   77700
# 13   78000
# 14  104800
# 15  117150
# 16  101000
# 17  103450
# 18  124750
# 19  137000

# %% [markdown]
# df[0:3]

# %%
df[0:9]
# Out:
#    Unnamed: 0       rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0           1       Prof          B             19           18  Male  139750
# 1           2       Prof          B             20           16  Male  173200
# 2           3   AsstProf          B              4            3  Male   79750
# 3           4       Prof          B             45           39  Male  115000
# 4           5       Prof          B             40           41  Male  141500
# 5           6  AssocProf          B              6            6  Male   97000
# 6           7       Prof          B             30           23  Male  175000
# 7           8       Prof          B             45           45  Male  147765
# 8           9       Prof          B             21           20  Male  119250

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['rank']
# Out:
# 0           Prof
# 1           Prof
# 2       AsstProf
# 3           Prof
# 4           Prof
# 5      AssocProf
# 6           Prof
# 7           Prof
# 8           Prof
# 9           Prof
# 10     AssocProf
# 11      AsstProf
# 12      AsstProf
# 13      AsstProf
# 14          Prof
# 15          Prof
# 16          Prof
# 17          Prof
# 18          Prof
# 19          Prof
# 20          Prof
# 21          Prof
# 22          Prof
# 23          Prof
# 24     AssocProf
# 25          Prof
# 26          Prof
# 27      AsstProf
# 28      AsstProf
# 29          Prof
#          ...
# 367    AssocProf
# 368         Prof
# 369         Prof
# 370    AssocProf
# 371         Prof
# 372         Prof
# 373         Prof
# 374         Prof
# 375         Prof
# 376     AsstProf
# 377     AsstProf
# 378         Prof
# 379    AssocProf
# 380     AsstProf
# 381         Prof
# 382    AssocProf
# 383         Prof
# 384         Prof
# 385         Prof
# 386         Prof
# 387         Prof
# 388         Prof
# 389         Prof
# 390         Prof
# 391         Prof
# 392         Prof
# 393         Prof
# 394         Prof
# 395         Prof
# 396     AsstProf
# Name: rank, dtype: object

# %%
type(df['rank'])
# Out:
# pandas.core.series.Series

# %%
df[['rank']]
# Out:
#           rank
# 0         Prof
# 1         Prof
# 2     AsstProf
# 3         Prof
# 4         Prof
# 5    AssocProf
# 6         Prof
# 7         Prof
# 8         Prof
# 9         Prof
# 10   AssocProf
# 11    AsstProf
# 12    AsstProf
# 13    AsstProf
# 14        Prof
# 15        Prof
# 16        Prof
# 17        Prof
# 18        Prof
# 19        Prof
# 20        Prof
# 21        Prof
# 22        Prof
# 23        Prof
# 24   AssocProf
# 25        Prof
# 26        Prof
# 27    AsstProf
# 28    AsstProf
# 29        Prof
# ..         ...
# 367  AssocProf
# 368       Prof
# 369       Prof
# 370  AssocProf
# 371       Prof
# 372       Prof
# 373       Prof
# 374       Prof
# 375       Prof
# 376   AsstProf
# 377   AsstProf
# 378       Prof
# 379  AssocProf
# 380   AsstProf
# 381       Prof
# 382  AssocProf
# 383       Prof
# 384       Prof
# 385       Prof
# 386       Prof
# 387       Prof
# 388       Prof
# 389       Prof
# 390       Prof
# 391       Prof
# 392       Prof
# 393       Prof
# 394       Prof
# 395       Prof
# 396   AsstProf
#
# [397 rows x 1 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'rank', 'discipline', 'yrs.since.phd', 'yrs.service',
#        'sex', 'salary'],
#       dtype='object')

# %%
list_of_cols_i_want = ['rank', 'discipline', 'sex']
df[list_of_cols_i_want]
# Out:
#           rank discipline     sex
# 0         Prof          B    Male
# 1         Prof          B    Male
# 2     AsstProf          B    Male
# 3         Prof          B    Male
# 4         Prof          B    Male
# 5    AssocProf          B    Male
# 6         Prof          B    Male
# 7         Prof          B    Male
# 8         Prof          B    Male
# 9         Prof          B  Female
# 10   AssocProf          B    Male
# 11    AsstProf          B    Male
# 12    AsstProf          B    Male
# 13    AsstProf          B    Male
# 14        Prof          B    Male
# 15        Prof          B    Male
# 16        Prof          B    Male
# 17        Prof          A    Male
# 18        Prof          A    Male
# 19        Prof          A  Female
# 20        Prof          A    Male
# 21        Prof          A    Male
# 22        Prof          A    Male
# 23        Prof          A    Male
# 24   AssocProf          A  Female
# 25        Prof          A    Male
# 26        Prof          A    Male
# 27    AsstProf          B    Male
# 28    AsstProf          B    Male
# 29        Prof          B    Male
# ..         ...        ...     ...
# 367  AssocProf          A    Male
# 368       Prof          A    Male
# 369       Prof          A    Male
# 370  AssocProf          A    Male
# 371       Prof          A    Male
# 372       Prof          A    Male
# 373       Prof          A    Male
# 374       Prof          A    Male
# 375       Prof          A    Male
# 376   AsstProf          A    Male
# 377   AsstProf          A    Male
# 378       Prof          A    Male
# 379  AssocProf          A    Male
# 380   AsstProf          A    Male
# 381       Prof          A    Male
# 382  AssocProf          A    Male
# 383       Prof          A    Male
# 384       Prof          A    Male
# 385       Prof          A    Male
# 386       Prof          A    Male
# 387       Prof          A    Male
# 388       Prof          A    Male
# 389       Prof          A    Male
# 390       Prof          A    Male
# 391       Prof          A    Male
# 392       Prof          A    Male
# 393       Prof          A    Male
# 394       Prof          A    Male
# 395       Prof          A    Male
# 396   AsstProf          A    Male
#
# [397 rows x 3 columns]

# %%
df.iloc[0:10, 2:4]
# Out:
#   discipline  yrs.since.phd
# 0          B             19
# 1          B             20
# 2          B              4
# 3          B             45
# 4          B             40
# 5          B              6
# 6          B             30
# 7          B             45
# 8          B             21
# 9          B             18

# %%
df.iloc[5,4]
# Out:
# 6

# %%
df.describe()
# Out:
#        Unnamed: 0  yrs.since.phd  yrs.service         salary
# count  397.000000     397.000000   397.000000     397.000000
# mean   199.000000      22.314861    17.614610  113706.458438
# std    114.748275      12.887003    13.006024   30289.038695
# min      1.000000       1.000000     0.000000   57800.000000
# 25%    100.000000      12.000000     7.000000   91000.000000
# 50%    199.000000      21.000000    16.000000  107300.000000
# 75%    298.000000      32.000000    27.000000  134185.000000
# max    397.000000      56.000000    60.000000  231545.000000

# %%
df = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/car/Salaries.csv')
df
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 0             1       Prof          B             19           18    Male
# 1             2       Prof          B             20           16    Male
# 2             3   AsstProf          B              4            3    Male
# 3             4       Prof          B             45           39    Male
# 4             5       Prof          B             40           41    Male
# 5             6  AssocProf          B              6            6    Male
# 6             7       Prof          B             30           23    Male
# 7             8       Prof          B             45           45    Male
# 8             9       Prof          B             21           20    Male
# 9            10       Prof          B             18           18  Female
# 10           11  AssocProf          B             12            8    Male
# 11           12   AsstProf          B              7            2    Male
# 12           13   AsstProf          B              1            1    Male
# 13           14   AsstProf          B              2            0    Male
# 14           15       Prof          B             20           18    Male
# 15           16       Prof          B             12            3    Male
# 16           17       Prof          B             19           20    Male
# 17           18       Prof          A             38           34    Male
# 18           19       Prof          A             37           23    Male
# 19           20       Prof          A             39           36  Female
# 20           21       Prof          A             31           26    Male
# 21           22       Prof          A             36           31    Male
# 22           23       Prof          A             34           30    Male
# 23           24       Prof          A             24           19    Male
# 24           25  AssocProf          A             13            8  Female
# 25           26       Prof          A             21            8    Male
# 26           27       Prof          A             35           23    Male
# 27           28   AsstProf          B              5            3    Male
# 28           29   AsstProf          B             11            0    Male
# 29           30       Prof          B             12            8    Male
# ..          ...        ...        ...            ...          ...     ...
# 367         368  AssocProf          A             10            1    Male
# 368         369       Prof          A             35           30    Male
# 369         370       Prof          A             33           31    Male
# 370         371  AssocProf          A             13            8    Male
# 371         372       Prof          A             23           20    Male
# 372         373       Prof          A             12            7    Male
# 373         374       Prof          A             30           26    Male
# 374         375       Prof          A             27           19    Male
# 375         376       Prof          A             28           26    Male
# 376         377   AsstProf          A              4            1    Male
# 377         378   AsstProf          A              6            3    Male
# 378         379       Prof          A             38           38    Male
# 379         380  AssocProf          A             11            8    Male
# 380         381   AsstProf          A              8            3    Male
# 381         382       Prof          A             27           23    Male
# 382         383  AssocProf          A              8            5    Male
# 383         384       Prof          A             44           44    Male
# 384         385       Prof          A             27           21    Male
# 385         386       Prof          A             15            9    Male
# 386         387       Prof          A             29           27    Male
# 387         388       Prof          A             29           15    Male
# 388         389       Prof          A             38           36    Male
# 389         390       Prof          A             33           18    Male
# 390         391       Prof          A             40           19    Male
# 391         392       Prof          A             30           19    Male
# 392         393       Prof          A             33           30    Male
# 393         394       Prof          A             31           19    Male
# 394         395       Prof          A             42           25    Male
# 395         396       Prof          A             25           15    Male
# 396         397   AsstProf          A              8            4    Male
#
#      salary
# 0    139750
# 1    173200
# 2     79750
# 3    115000
# 4    141500
# 5     97000
# 6    175000
# 7    147765
# 8    119250
# 9    129000
# 10   119800
# 11    79800
# 12    77700
# 13    78000
# 14   104800
# 15   117150
# 16   101000
# 17   103450
# 18   124750
# 19   137000
# 20    89565
# 21   102580
# 22    93904
# 23   113068
# 24    74830
# 25   106294
# 26   134885
# 27    82379
# 28    77000
# 29   118223
# ..      ...
# 367  108413
# 368  131950
# 369  134690
# 370   78182
# 371  110515
# 372  109707
# 373  136660
# 374  103275
# 375  103649
# 376   74856
# 377   77081
# 378  150680
# 379  104121
# 380   75996
# 381  172505
# 382   86895
# 383  105000
# 384  125192
# 385  114330
# 386  139219
# 387  109305
# 388  119450
# 389  186023
# 390  166605
# 391  151292
# 392  103106
# 393  150564
# 394  101738
# 395   95329
# 396   81035
#
# [397 rows x 7 columns]

# %%
df.describe()
# Out:
#        Unnamed: 0  yrs.since.phd  yrs.service         salary
# count  397.000000     397.000000   397.000000     397.000000
# mean   199.000000      22.314861    17.614610  113706.458438
# std    114.748275      12.887003    13.006024   30289.038695
# min      1.000000       1.000000     0.000000   57800.000000
# 25%    100.000000      12.000000     7.000000   91000.000000
# 50%    199.000000      21.000000    16.000000  107300.000000
# 75%    298.000000      32.000000    27.000000  134185.000000
# max    397.000000      56.000000    60.000000  231545.000000

# %%
df.describe(percentiles=[.95, .99])
# Out:
#        Unnamed: 0  yrs.since.phd  yrs.service         salary
# count  397.000000     397.000000   397.000000     397.000000
# mean   199.000000      22.314861    17.614610  113706.458438
# std    114.748275      12.887003    13.006024   30289.038695
# min      1.000000       1.000000     0.000000   57800.000000
# 50%    199.000000      21.000000    16.000000  107300.000000
# 95%    377.200000      45.000000    41.400000  168908.000000
# 99%    393.040000      51.040000    49.080000  193072.000000
# max    397.000000      56.000000    60.000000  231545.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 7 columns):
# Unnamed: 0       397 non-null int64
# rank             397 non-null object
# discipline       397 non-null object
# yrs.since.phd    397 non-null int64
# yrs.service      397 non-null int64
# sex              397 non-null object
# salary           397 non-null int64
# dtypes: int64(4), object(3)
# memory usage: 21.8+ KB

# %%
df['salary'].hist()

# %%
df['salary'].hist(figsize=(10,8), color='k')

# %%
fig = df['yrs_since_phd'].hist(figsize=(12,6), color='darkorange')
plt.style.use('fivethirtyeight')

# get the current axis
ax = plt.gca()

ax.set_ylabel('Frequency', fontsize=14)
ax.set_xlabel('Years', fontsize=14)
ax.set_title('A Chart of Stuff', y=1.01)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Applications/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'yrs_since_phd'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-83-b0f0a44b0e7e> in <module>()
# ----> 1 fig = df['yrs_since_phd'].hist(figsize=(12,6), color='darkorange')
#       2 plt.style.use('fivethirtyeight')
#       3
#       4 # get the current axis
#       5 ax = plt.gca()
#
# /Applications/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /Applications/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /Applications/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /Applications/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Applications/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'yrs_since_phd'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
trials = 100000.
data = n.random.randint(2, size = (trials, 30)) #as we increase the sample size, we appriach a normal distribution
N = np.sum(data, axis = 1) # sum up the number of heads in rows (experiments)
plt.hist(N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-1905f0d09c4d> in <module>()
#       3 import numpy as np
#       4 trials = 100000.
# ----> 5 data = n.random.randint(2, size = (trials, 30)) #as we increase the sample size, we appriach a normal distribution
#       6 N = np.sum(data, axis = 1) # sum up the number of heads in rows (experiments)
#       7 plt.hist(N)
#
# NameError: name 'n' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-c02e9e223cf9> in <module>()
# ----> 1 int_rate.describe()
#
# NameError: name 'int_rate' is not defined
