# %%
import numpy as np
import scipy.stats as stats
import csv
import seaborn as sns
# %matplotlib inline
import pandas as pd
sat_scores_path = '/Users/supermaxfederman/DSI-NYC-2/projects/projects-weekly/project-01/assets/sat_scores.csv'

# %%
### 1. Data shows all States SAT scores for Math and Verbal and their rate. 
### 2. Unclear what the "Rate" is referring to
### 3. State refers to the State where tests are being taken, Rate (I assume) refers to the percentage of 
### students taking the SAT in that State, Verbal refers to average SAT Verbal section score of students in
### in that state, and Math refers to the average SAT Math section score of students in that state.

# %%
sat_data = {}
for index, column_name in enumerate(header):
    sat_data[column_name]=[]
    for row in data:
        sat_data[column_name].append(row[index])

# %%
states = sat_data['State'][0:52]
rates = sat_data['Rate'][0:52]
verbs = sat_data['Verbal'][0:52]
maths = sat_data['Math'][0:52]

# %%
sat_data['State']
# Out:
# ['CT',
#  'NJ',
#  'MA',
#  'NY',
#  'NH',
#  'RI',
#  'PA',
#  'VT',
#  'ME',
#  'VA',
#  'DE',
#  'MD',
#  'NC',
#  'GA',
#  'IN',
#  'SC',
#  'DC',
#  'OR',
#  'FL',
#  'WA',
#  'TX',
#  'HI',
#  'AK',
#  'CA',
#  'AZ',
#  'NV',
#  'CO',
#  'OH',
#  'MT',
#  'WV',
#  'ID',
#  'TN',
#  'NM',
#  'IL',
#  'KY',
#  'WY',
#  'MI',
#  'MN',
#  'KS',
#  'AL',
#  'NE',
#  'OK',
#  'MO',
#  'LA',
#  'WI',
#  'AR',
#  'UT',
#  'IA',
#  'SD',
#  'ND',
#  'MS',
#  'All']

# %%
### 4
data = rows[1:]
###5
print(data)
# Out:
# [['CT', '82', '509', '510'], ['NJ', '81', '499', '513'], ['MA', '79', '511', '515'], ['NY', '77', '495', '505'], ['NH', '72', '520', '516'], ['RI', '71', '501', '499'], ['PA', '71', '500', '499'], ['VT', '69', '511', '506'], ['ME', '69', '506', '500'], ['VA', '68', '510', '501'], ['DE', '67', '501', '499'], ['MD', '65', '508', '510'], ['NC', '65', '493', '499'], ['GA', '63', '491', '489'], ['IN', '60', '499', '501'], ['SC', '57', '486', '488'], ['DC', '56', '482', '474'], ['OR', '55', '526', '526'], ['FL', '54', '498', '499'], ['WA', '53', '527', '527'], ['TX', '53', '493', '499'], ['HI', '52', '485', '515'], ['AK', '51', '514', '510'], ['CA', '51', '498', '517'], ['AZ', '34', '523', '525'], ['NV', '33', '509', '515'], ['CO', '31', '539', '542'], ['OH', '26', '534', '439'], ['MT', '23', '539', '539'], ['WV', '18', '527', '512'], ['ID', '17', '543', '542'], ['TN', '13', '562', '553'], ['NM', '13', '551', '542'], ['IL', '12', '576', '589'], ['KY', '12', '550', '550'], ['WY', '11', '547
# ...

# %%
### 6
rows = []

with open(sat_scores_path, 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        rows.append(row)
header = rows[0]
print(header)
# Out:
# ['State', 'Rate', 'Verbal', 'Math']

# %%
### 7
states
# Out:
# ['CT',
#  'NJ',
#  'MA',
#  'NY',
#  'NH',
#  'RI',
#  'PA',
#  'VT',
#  'ME',
#  'VA',
#  'DE',
#  'MD',
#  'NC',
#  'GA',
#  'IN',
#  'SC',
#  'DC',
#  'OR',
#  'FL',
#  'WA',
#  'TX',
#  'HI',
#  'AK',
#  'CA',
#  'AZ',
#  'NV',
#  'CO',
#  'OH',
#  'MT',
#  'WV',
#  'ID',
#  'TN',
#  'NM',
#  'IL',
#  'KY',
#  'WY',
#  'MI',
#  'MN',
#  'KS',
#  'AL',
#  'NE',
#  'OK',
#  'MO',
#  'LA',
#  'WI',
#  'AR',
#  'UT',
#  'IA',
#  'SD',
#  'ND',
#  'MS',
#  'All']

# %%
### 8 
statesarray = np.asarray(states)
statesarray
# Out:
# array(['CT', 'NJ', 'MA', 'NY', 'NH', 'RI', 'PA', 'VT', 'ME', 'VA', 'DE',
#        'MD', 'NC', 'GA', 'IN', 'SC', 'DC', 'OR', 'FL', 'WA', 'TX', 'HI',
#        'AK', 'CA', 'AZ', 'NV', 'CO', 'OH', 'MT', 'WV', 'ID', 'TN', 'NM',
#        'IL', 'KY', 'WY', 'MI', 'MN', 'KS', 'AL', 'NE', 'OK', 'MO', 'LA',
#        'WI', 'AR', 'UT', 'IA', 'SD', 'ND', 'MS', 'All'],
#       dtype='<U3')

# %%
ratesarray = np.asarray(rates)
ratesarray
# Out:
# array(['82', '81', '79', '77', '72', '71', '71', '69', '69', '68', '67',
#        '65', '65', '63', '60', '57', '56', '55', '54', '53', '53', '52',
#        '51', '51', '34', '33', '31', '26', '23', '18', '17', '13', '13',
#        '12', '12', '11', '11', '9', '9', '9', '8', '8', '8', '7', '6', '6',
#        '5', '5', '4', '4', '4', '45'],
#       dtype='<U2')

# %%
verbsarray = np.asarray(verbs)
verbsarray
# Out:
# numpy.ndarray

# %%
matharray = np.asarray(maths)
matharray
# Out:
# array(['510', '513', '515', '505', '516', '499', '499', '506', '500',
#        '501', '499', '510', '499', '489', '501', '488', '474', '526',
#        '499', '527', '499', '515', '510', '517', '525', '515', '542',
#        '439', '539', '512', '542', '553', '542', '589', '550', '545',
#        '572', '589', '580', '554', '568', '561', '577', '562', '596',
#        '550', '570', '603', '582', '599', '551', '514'],
#       dtype='<U3')

# %%
### 9 (reassign some to int's if they are strings...)
rates = map(int, rates)
rates
verbs = map(int, verbs)
verbs
maths = map(int, maths)
maths

# %%
### 10 create dictionary showing ['state', number] for rate math and verbal

# %%
states
rates
sdictionary = dict(zip(states, rates))
print(sdictionary)
# Out:
# {'RI': 71, 'OK': 8, 'CT': 82, 'AL': 9, 'WI': 6, 'FL': 54, 'CO': 31, 'DC': 56, 'DE': 67, 'All': 45, 'OH': 26, 'MD': 65, 'IA': 5, 'WV': 18, 'HI': 52, 'NH': 72, 'KY': 12, 'PA': 71, 'WA': 53, 'ID': 17, 'LA': 7, 'ND': 4, 'IN': 60, 'MA': 79, 'MS': 4, 'TX': 53, 'SD': 4, 'GA': 63, 'AR': 6, 'MO': 8, 'ME': 69, 'NY': 77, 'AZ': 34, 'UT': 5, 'OR': 55, 'KS': 9, 'MT': 23, 'WY': 11, 'SC': 57, 'NC': 65, 'CA': 51, 'IL': 12, 'AK': 51, 'VA': 68, 'TN': 13, 'MN': 9, 'MI': 11, 'VT': 69, 'NJ': 81, 'NE': 8, 'NM': 13, 'NV': 33}

# %%
states
maths
mdictionary = dict(zip(states, maths))
print(mdictionary)
# Out:
# {'RI': 499, 'OK': 561, 'CT': 510, 'AL': 554, 'WI': 596, 'FL': 499, 'CO': 542, 'DC': 474, 'DE': 499, 'All': 514, 'OH': 439, 'MD': 510, 'IA': 603, 'WV': 512, 'HI': 515, 'NH': 516, 'KY': 550, 'PA': 499, 'WA': 527, 'ID': 542, 'LA': 562, 'ND': 599, 'IN': 501, 'MA': 515, 'MS': 551, 'TX': 499, 'SD': 582, 'GA': 489, 'AR': 550, 'MO': 577, 'ME': 500, 'NY': 505, 'AZ': 525, 'UT': 570, 'OR': 526, 'KS': 580, 'MT': 539, 'WY': 545, 'SC': 488, 'NC': 499, 'CA': 517, 'IL': 589, 'AK': 510, 'VA': 501, 'TN': 553, 'MN': 589, 'MI': 572, 'VT': 506, 'NJ': 513, 'NE': 568, 'NM': 542, 'NV': 515}

# %%
states
verbs
vdictionary = dict(zip(states, verbs))
print(vdictionary)
# Out:
# {'RI': 501, 'OK': 567, 'CT': 509, 'AL': 559, 'WI': 584, 'FL': 498, 'CO': 539, 'DC': 482, 'DE': 501, 'All': 506, 'OH': 534, 'MD': 508, 'IA': 593, 'WV': 527, 'HI': 485, 'NH': 520, 'KY': 550, 'PA': 500, 'WA': 527, 'ID': 543, 'LA': 564, 'ND': 592, 'IN': 499, 'MA': 511, 'MS': 566, 'TX': 493, 'SD': 577, 'GA': 491, 'AR': 562, 'MO': 577, 'ME': 506, 'NY': 495, 'AZ': 523, 'UT': 575, 'OR': 526, 'KS': 577, 'MT': 539, 'WY': 547, 'SC': 486, 'NC': 493, 'CA': 498, 'IL': 576, 'AK': 514, 'VA': 510, 'TN': 562, 'MN': 580, 'MI': 561, 'VT': 511, 'NJ': 499, 'NE': 562, 'NM': 551, 'NV': 509}

# %%
### 11 Create a dictionary with the values for each of the numeric columns
print(sat_data)
# Out:
# {'Rate': ['82', '81', '79', '77', '72', '71', '71', '69', '69', '68', '67', '65', '65', '63', '60', '57', '56', '55', '54', '53', '53', '52', '51', '51', '34', '33', '31', '26', '23', '18', '17', '13', '13', '12', '12', '11', '11', '9', '9', '9', '8', '8', '8', '7', '6', '6', '5', '5', '4', '4', '4', '45'], 'Math': ['510', '513', '515', '505', '516', '499', '499', '506', '500', '501', '499', '510', '499', '489', '501', '488', '474', '526', '499', '527', '499', '515', '510', '517', '525', '515', '542', '439', '539', '512', '542', '553', '542', '589', '550', '545', '572', '589', '580', '554', '568', '561', '577', '562', '596', '550', '570', '603', '582', '599', '551', '514'], 'State': ['CT', 'NJ', 'MA', 'NY', 'NH', 'RI', 'PA', 'VT', 'ME', 'VA', 'DE', 'MD', 'NC', 'GA', 'IN', 'SC', 'DC', 'OR', 'FL', 'WA', 'TX', 'HI', 'AK', 'CA', 'AZ', 'NV', 'CO', 'OH', 'MT', 'WV', 'ID', 'TN', 'NM', 'IL', 'KY', 'WY', 'MI', 'MN', 'KS', 'AL', 'NE', 'OK', 'MO', 'LA', 'WI', 'AR', 'UT', 'IA', 'SD', 'ND', 'MS',
# ...

# %%
### 12 print max and min of each column (fix Rate)
rate_min = min(int_rate)
rate_max = max(int_rate)
print("The Min of Rate is "+ str(rate_min))
print("The Max of Rate is "+ str(rate_max))
# Out:
# The Min of Rate is 4
# The Max of Rate is 82

# %%
verb_min = min(int_verb)
verb_max = max(int_verb)
print("The Min of Verbal is "+ str(verb_min))
print("The Max of Verbal is "+ str(verb_max))
# Out:
# The Min of Verbal is 482
# The Max of Verbal is 593

# %%
math_min = min(int_math)
math_max = max(int_math)
print("The Min of Math is "+ str(math_min))
print("The Max of Math is "+ str(math_max))
# Out:
# The Min of Math is 439
# The Max of Math is 603

# %%
import pandas as pd

# %%
### 13
my_std() = [
    (((n - mean)**2)/sat_data.len())
    for n in sat_data]
# Out:
#   File "<ipython-input-170-21af7f7be9bf>", line 2
#     my_std() = [
#                 ^
# SyntaxError: can't assign to function call

# %%
###14

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(15,7))


x = range(len(sdictionary))
y = sdictionary.values()

# set the title, make it bigger, and move it up in the y-direction
ax.set_title('Participation Rate by State', fontsize=18, y=1.01)

# set the x tick labels and center
ax.set_xticks(x)
ax.set_xticklabels(sdictionary.keys())

# add some margin
ax.set_ylim(0, max(sdictionary.values()) * 1.1)
ax.set_xlim(-1,len(sdictionary))

# chang the color
plt.bar(x, y, align='center', color='r')
# Out:
# <Container object of 52 artists>

# %%
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (60.0, 30.0)


d = sdictionary
X = range(len(d))
pl.bar(X, d.values(), align='center', width=1.0)
pl.xticks(X, d.keys(), fontsize = 35)
pl.ylabel('Rates', fontsize=30)
pl.xlabel('States', fontsize=30)
ymax = max(d.values()) + 2
pl.ylim(0, ymax) 
pl.xlim(-3, len(d)+3)

pl.show();
## Need to spead out bars more

# %%
#15

# %%
import pylab as pl
import numpy as np

d = mdictionary
X = range(len(d))
pl.bar(X, d.values(), align='center', width=1)
pl.xticks(X, d.keys(), fontsize = 35)
ymax = max(d.values()) + 2
pl.ylim(0, ymax)
pl.xlim(-5, len(mdictionary)+5)
pl.show()

# %%
#16

# %%
import pylab as pl
import numpy as np

d = vdictionary
X = range(len(d))
pl.bar(X, d.values(), align='center', width=2)
pl.xticks(X, d.keys(), fontsize = 35)
ymax = max(d.values()) + 2
pl.ylim(0, ymax)
pl.xlim(-5, len(vdictionary)+5)
pl.show()

# %%
#17 We must assume that the data is normally distributed

# %%
#18 Yes

# %%
#19

# %%
#20

# %%
#21
