# %%
def calculate_distance(p, q):
    """ Calculate Euclidean distance between two points."""
    return ((p[0]-q[0]**2)+(p[1]-q[1]**2))**0.5

# %%
import collections
labels = ['a', 'b', 'c', 'c']
print(collections.Counter(labels))

def neighbor_vote(labels):
    """ Get the majority label from k neighbors."""
    # Is it possible to have a tie? How would you handle that?
    vote = collections.Counter(labels).most_common(1)[0][0]
    return vote
# Out:
# Counter({'c': 2, 'b': 1, 'a': 1})

# %%
def knn_classifier(labeled_points, new_point, k):
    """ Given classified points and one new point, return a prediction based on the votes of k neighbors."""
    if k%2==0:
        return "Must use odd k, to prevent ties"
    label_distances = []
    
    for p in labeled_points:
        distance = calculate_distance(p[0], new_point)
        label_distances.Append(distance, p[1])
        
    label_distances.sort()
    prediction = neighbor_vote([label[1] for label in label_distances[:k]])
    return prediction

# %%
from sklearn import datasets
import pandas as pd
import numpy as np
from sklearn.cross_validation import train_test_split

# import data
iris = datasets.load_iris()
X = iris.data[:100, :2]  # use the first two features and just the first two classes.
y = iris.target[:100]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# Split 70/30 into initial data and new points to classify
training_df = pd.DataFrame({'feature1':X_train[:,0],'feature2':X_train[:,1],'class':y_train})
test_df = pd.DataFrame({'feature1':X_test[:,0],'feature2':X_test[:,1],'class':y_test})

# %%
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

sns.lmplot('feature1', 'feature2', 
           data=training_df, 
           fit_reg=False, 
           hue="class")

# %%
print(labeled_points)
# Out:
# <zip object at 0x11f9d66c8>

# %%
test_df
# Out:
#     class  feature1  feature2
# 0       1       6.0       2.7
# 1       1       5.5       2.3
# 2       1       5.9       3.2
# 3       0       4.8       3.0
# 4       0       5.1       3.8
# 5       0       5.1       3.4
# 6       0       4.6       3.6
# 7       1       5.5       2.4
# 8       0       5.4       3.7
# 9       0       5.1       3.5
# 10      0       5.7       3.8
# 11      0       4.8       3.1
# 12      1       6.1       2.8
# 13      0       5.5       4.2
# 14      1       5.5       2.6
# 15      0       5.0       3.6
# 16      1       6.8       2.8
# 17      1       6.7       3.0
# 18      0       4.8       3.0
# 19      0       5.4       3.4
# 20      1       5.7       2.8
# 21      1       5.6       3.0
# 22      0       5.0       3.4
# 23      0       4.4       3.2
# 24      1       5.6       2.5
# 25      0       5.7       4.4
# 26      0       5.0       3.5
# 27      1       5.7       2.9
# 28      0       4.9       3.1
# 29      1       6.3       2.5

# %%
training_df
# Out:
#     class  feature1  feature2
# 0       0       4.8       3.4
# 1       0       4.6       3.2
# 2       1       6.0       3.4
# 3       0       5.2       3.4
# 4       1       5.0       2.3
# 5       0       5.4       3.9
# 6       1       5.6       3.0
# 7       1       6.7       3.1
# 8       0       5.0       3.2
# 9       0       5.4       3.9
# 10      0       5.0       3.3
# 11      0       4.9       3.1
# 12      0       5.0       3.4
# 13      1       5.7       3.0
# 14      0       5.2       3.5
# 15      0       5.1       3.8
# 16      1       5.5       2.4
# 17      0       5.0       3.0
# 18      1       6.0       2.2
# 19      0       4.3       3.0
# 20      0       4.8       3.4
# 21      0       4.6       3.1
# 22      0       5.1       3.5
# 23      0       4.4       3.0
# 24      0       4.4       2.9
# 25      1       6.0       2.9
# 26      0       4.6       3.4
# 27      1       5.6       2.9
# 28      0       5.5       3.5
# 29      1       5.5       2.5
# ..    ...       ...       ...
# 40      1       5.7       2.6
# 41      0       4.5       2.3
# 42      1       6.6       2.9
# 43      0       5.3       3.7
# 44      1       5.1       2.5
# 45      1       4.9       2.4
# 46      1       6.6       3.0
# 47      0       5.2       4.1
# 48      1       5.6       2.7
# 49      1       5.2       2.7
# 50      1       6.1       2.9
# 51      1       5.4       3.0
# 52      0       4.9       3.1
# 53      0       4.7       3.2
# 54      0       4.9       3.0
# 55      1       6.9       3.1
# 56      0       5.1       3.7
# 57      0       4.7       3.2
# 58      0       5.1       3.3
# 59      1       6.3       2.3
# 60      1       6.1       3.0
# 61      1       6.4       2.9
# 62      1       6.7       3.1
# 63      1       5.8       2.7
# 64      0       5.4       3.4
# 65      1       5.0       2.0
# 66      1       6.1       2.8
# 67      0       5.8       4.0
# 68      1       5.8       2.6
# 69      1       6.4       3.2
#
# [70 rows x 3 columns]

# %%
""" Iteratively classify new points in test_df, based on the labeled points in training_df, and track your accuracy."""

#print(training_df[:5])

training = training_df.T.values.tolist()
labeled_points = zip(zip(training[1],training[2]),training[0])

#print(labeled_points[:5])

knn_classifier(labeled_points, ((6.0,2.5)),k=5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-979c8a0782ab> in <module>()
#       8 #print(labeled_points[:5])
#       9
# ---> 10 knn_classifier(labeled_points, ((6.0,2.5)),k=5)
#
# <ipython-input-52-495838b52d45> in knn_classifier(labeled_points, new_point, k)
#       7     for p in labeled_points:
#       8         distance = calculate_distance(p[0], new_point)
# ----> 9         label_distances.Append(distance, p[1])
#      10
#      11     label_distances.sort()
#
# AttributeError: 'list' object has no attribute 'Append'

# %%
""" BONUS: plot the labeled points and an example of a new point being classified."""
# Out:
# ' BONUS: plot the labeled points and an example of a new point being classified.'
